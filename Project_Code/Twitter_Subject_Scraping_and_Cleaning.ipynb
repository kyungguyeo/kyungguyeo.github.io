# %%
import datetime
from datetime import datetime as dt
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
import json

tjson=[]

#Set search parameters for model subject tweets to be webscraped.
firsttime = dt.now()

year=2013
disease="adhd"
startdate = datetime.date(2013, 2, 1)
enddate = datetime.date(2018, 4, 1)
daterange = [startdate]

while startdate < enddate:
    if not startdate.month % 12:
        startdate = datetime.date(startdate.year+1, 1, 1)
    else:
        startdate = datetime.date(startdate.year, startdate.month+1, 1)
    daterange.append(startdate)

# querylist=[
#     "I was recently diagnosed with "+disease,
#     "I was diagnosed with "+disease
# ]
    
    
querylist=[ "my nutritionist",
           "my foodstamps"

]

labellist=[0,1]

newrange = daterange[0::2]

for index,searchdate in enumerate(newrange[:-1]):
    start = newrange[index].strftime('%Y-%-m-%d')
    if newrange[index].month==12:
        newmonth=1
    else:
        newmonth=newrange[index].month+1
    end = datetime.date(newrange[index].year, newmonth, 1).strftime('%Y-%-m-%d')
    for label,query in zip(labellist,querylist):
        #Query tweets from search page
        print
        print('Collecting "%s" tweets from %s to %s at %s'%(query,start,end,dt.now()))
        print
        startTime = dt.now()
        q=query.replace(' ','%20')
        prefix='https://twitter.com/search?f=tweets&vertical=default&q=%22'
        browser = webdriver.Chrome('./chromedriver')
        #browser = webdriver.Firefox()
        #browser = webdriver.Safari()
        browser.get(prefix+q+'%22%20since%3A'+start+'%20until%3A'+end+'&src=typd')

        #Scroll to bottom of search results page to webscrape all results.
        while True:
            elemsCount = browser.execute_script("return document.querySelectorAll('.stream-items > li.stream-item').length")
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
            try:
                WebDriverWait(browser, 2).until(lambda x: x.find_element_by_xpath(
                    "//*[contains(@class,'stream-items')]/li[contains(@class,'stream-item')]["+str(elemsCount+1)+"]"))
            except:
                break  

        #Get lists of all tweets, usernames, and dates
        tweets = browser.find_elements_by_class_name('js-tweet-text')
        tweetids = browser.find_elements_by_class_name('original-tweet')
        users = browser.find_elements_by_css_selector('.original-tweet')
        dates = browser.find_elements_by_class_name('tweet-timestamp')

        twtcnt=0

        #Loop through tweet info and assign to dict
        for user,date,tweetid,tweet in zip(users,dates,tweetids,tweets):
            tdata={}
            _tweetid=tweetid.get_attribute("data-tweet-id")
            _tweetdate=date.get_attribute('title')
            _user=user.get_attribute('data-screen-name')
            _tweettext=tweet.text#.encode('utf-8').decode("utf-8").encode("ascii","ignore")
            tdata['username']=_user
            tdata['key_phrase']=query
            tdata['marker_tweet']=_tweettext
            tdata['marker_tweet_id']=_tweetid
            tdata['marker_tweet_date']=_tweetdate
            tdata['label']=label

            if any(['bot' in _user]):
                continue
                

            twtcnt+=1

            tjson.append(tdata)


            if twtcnt % 100 == 0:
                print('-----%s tweets collected at %s.'%(twtcnt,dt.now()))
        browser.quit()
        print('-----%s "%s" tweets collected in %s seconds.'%(twtcnt,query,dt.now()-startTime))
    
print
print
print
print('Total Time: %s'%(dt.now()-firsttime))

#Write dicts to json file.
with open('food_risk_train_set2.json', 'w') as outfile:
    outfile.write(json.dumps(tjson))
# Out:
# Collecting "my nutritionist" tweets from 2013-2-01 to 2013-3-01 at 2018-04-16 23:37:35.062532
# -----100 tweets collected at 2018-04-16 23:38:15.199393.
# -----200 tweets collected at 2018-04-16 23:38:20.909346.
# -----300 tweets collected at 2018-04-16 23:38:26.705709.
# -----400 tweets collected at 2018-04-16 23:38:32.510753.
# -----500 tweets collected at 2018-04-16 23:38:38.369922.
# -----600 tweets collected at 2018-04-16 23:38:44.406367.
# -----642 "my nutritionist" tweets collected in 0:01:11.983078 seconds.
# Collecting "my foodstamps" tweets from 2013-2-01 to 2013-3-01 at 2018-04-16 23:38:47.045919
# -----100 tweets collected at 2018-04-16 23:39:21.298419.
# -----200 tweets collected at 2018-04-16 23:39:26.493467.
# -----300 tweets collected at 2018-04-16 23:39:31.840777.
# -----400 tweets collected at 2018-04-16 23:39:37.157161.
# -----500 tweets collected at 2018-04-16 23:39:42.614104.
# -----574 "my foodstamps" tweets collected in 0:00:59.617022 seconds.
# Collecting "my nutritionist" tweets from 2013-4-01 to 2013-5-01 at 2018-04-16 23:39:46.663183
# -----100 tweets collected at 2018-04-16 23:40:13.034712.
# -----200 tweets collected at 2018-04-16 23:40:19.699794.
# -----300 tweets collected at 2018-04-16 23:40:28.223374.
# -----339 "my nutritionist" tweets collected in 0:00:44.541319 seconds.
# Collecting "my foodstamps" tweets from 2013-4-01 to 2013-5-01 at 2018-04-16 23:40:31.204724
# -----100 tweets collected at 2018-04-16 23:41:04.023661.
# -----200 tweets collected at 2018-04-16 23:41:09.521007.
# -----300 tweets collected at 2018-04-16 23:41:15.127980.
# -----400 tweets collected at 2018-04-16 23:41:21.104039.
# -----454 "my foodstamps" tweets collected in 0:00:53.346264 seconds.
# Collecting "my nutritionist" tweets from 2013-6-01 to 2013-7-01 at 2018-04-16 23:41:24.551233
# -----100 tweets collected at 2018-04-16 23:41:55.100794.
# -----200 tweets collected at 2018-04-16 23:42:00.388931.
# -----300 tweets collected at 2018-04-16 23:42:05.896606.
# -----400 tweets collected at 2018-04-16 23:42:11.708569.
# -----438 "my nutritionist" tweets collected in 0:00:49.378343 seconds.
# Collecting "my foodstamps" tweets from 2013-6-01 to 2013-7-01 at 2018-04-16 23:42:13.929739
# -----100 tweets collected at 2018-04-16 23:42:52.286727.
# -----200 tweets collected at 2018-04-16 23:42:59.346080.
# -----300 tweets collected at 2018-04-16 23:43:07.326397.
# -----400 tweets collected at 2018-04-16 23:43:16.054616.
# -----500 tweets collected at 2018-04-16 23:43:25.229227.
# -----521 "my foodstamps" tweets collected in 0:01:13.308569 seconds.
# Collecting "my nutritionist" tweets from 2013-8-01 to 2013-9-01 at 2018-04-16 23:43:27.238735
# -----100 tweets collected at 2018-04-16 23:43:59.364144.
# -----200 tweets collected at 2018-04-16 23:44:05.061055.
# -----300 tweets collected at 2018-04-16 23:44:11.225080.
# -----400 tweets collected at 2018-04-16 23:44:17.219893.
# -----476 "my nutritionist" tweets collected in 0:00:54.847426 seconds.
# Collecting "my foodstamps" tweets from 2013-8-01 to 2013-9-01 at 2018-04-16 23:44:22.086336
# -----100 tweets collected at 2018-04-16 23:44:56.599981.
# -----200 tweets collected at 2018-04-16 23:45:02.337602.
# -----300 tweets collected at 2018-04-16 23:45:07.896595.
# -----400 tweets collected at 2018-04-16 23:45:13.775320.
# -----499 "my foodstamps" tweets collected in 0:00:57.828246 seconds.
# Collecting "my nutritionist" tweets from 2013-10-01 to 2013-11-01 at 2018-04-16 23:45:19.914846
# -----100 tweets collected at 2018-04-16 23:45:52.457995.
# -----200 tweets collected at 2018-04-16 23:46:01.486297.
# -----300 tweets collected at 2018-04-16 23:46:10.287778.
# -----400 tweets collected at 2018-04-16 23:46:20.938838.
# -----430 "my nutritionist" tweets collected in 0:01:04.126960 seconds.
# Collecting "my foodstamps" tweets from 2013-10-01 to 2013-11-01 at 2018-04-16 23:46:24.041951
# -----100 tweets collected at 2018-04-16 23:47:16.531196.
# -----200 tweets collected at 2018-04-16 23:47:23.961007.
# -----300 tweets collected at 2018-04-16 23:47:34.789331.
# -----400 tweets collected at 2018-04-16 23:47:43.330978.
# -----500 tweets collected at 2018-04-16 23:47:52.428876.
# -----600 tweets collected at 2018-04-16 23:48:01.331755.
# -----700 tweets collected at 2018-04-16 23:48:11.690772.
# -----800 tweets collected at 2018-04-16 23:48:21.146836.
# -----834 "my foodstamps" tweets collected in 0:02:00.506760 seconds.
# Collecting "my nutritionist" tweets from 2013-12-01 to 2013-1-01 at 2018-04-16 23:48:24.549072
# -----0 "my nutritionist" tweets collected in 0:00:05.388552 seconds.
# Collecting "my foodstamps" tweets from 2013-12-01 to 2013-1-01 at 2018-04-16 23:48:29.937820
# -----0 "my foodstamps" tweets collected in 0:00:05.198072 seconds.
# Collecting "my nutritionist" tweets from 2014-2-01 to 2014-3-01 at 2018-04-16 23:48:35.136256
# -----100 tweets collected at 2018-04-16 23:49:03.570390.
# -----200 tweets collected at 2018-04-16 23:49:08.979891.
# -----300 tweets collected at 2018-04-16 23:49:14.270518.
# -----400 tweets collected at 2018-04-16 23:49:19.291322.
# -----408 "my nutritionist" tweets collected in 0:00:44.647223 seconds.
# Collecting "my foodstamps" tweets from 2014-2-01 to 2014-3-01 at 2018-04-16 23:49:19.783650
# -----100 tweets collected at 2018-04-16 23:49:41.240651.
# -----200 tweets collected at 2018-04-16 23:49:46.012905.
# -----257 "my foodstamps" tweets collected in 0:00:28.983970 seconds.
# Collecting "my nutritionist" tweets from 2014-4-01 to 2014-5-01 at 2018-04-16 23:49:48.767887
# -----100 tweets collected at 2018-04-16 23:50:17.822584.
# -----200 tweets collected at 2018-04-16 23:50:22.936452.
# -----300 tweets collected at 2018-04-16 23:50:30.040603.
# -----389 "my nutritionist" tweets collected in 0:00:48.301919 seconds.
# Collecting "my foodstamps" tweets from 2014-4-01 to 2014-5-01 at 2018-04-16 23:50:37.070001
# -----100 tweets collected at 2018-04-16 23:50:57.657290.
# -----200 tweets collected at 2018-04-16 23:51:02.215174.
# -----241 "my foodstamps" tweets collected in 0:00:27.154498 seconds.
# Collecting "my nutritionist" tweets from 2014-6-01 to 2014-7-01 at 2018-04-16 23:51:04.224845
# -----100 tweets collected at 2018-04-16 23:51:29.526578.
# -----200 tweets collected at 2018-04-16 23:51:34.527364.
# -----300 tweets collected at 2018-04-16 23:51:39.334801.
# -----373 "my nutritionist" tweets collected in 0:00:38.772039 seconds.
# Collecting "my foodstamps" tweets from 2014-6-01 to 2014-7-01 at 2018-04-16 23:51:42.997054
# -----100 tweets collected at 2018-04-16 23:52:02.048749.
# -----200 tweets collected at 2018-04-16 23:52:06.336322.
# -----226 "my foodstamps" tweets collected in 0:00:24.519164 seconds.
# Collecting "my nutritionist" tweets from 2014-8-01 to 2014-9-01 at 2018-04-16 23:52:07.516627
# -----100 tweets collected at 2018-04-16 23:52:31.977717.
# -----200 tweets collected at 2018-04-16 23:52:36.497830.
# -----300 tweets collected at 2018-04-16 23:52:41.259082.
# -----326 "my nutritionist" tweets collected in 0:00:35.028249 seconds.
# Collecting "my foodstamps" tweets from 2014-8-01 to 2014-9-01 at 2018-04-16 23:52:42.545090
# -----100 tweets collected at 2018-04-16 23:53:02.290791.
# -----200 tweets collected at 2018-04-16 23:53:06.658630.
# -----235 "my foodstamps" tweets collected in 0:00:25.771677 seconds.
# Collecting "my nutritionist" tweets from 2014-10-01 to 2014-11-01 at 2018-04-16 23:53:08.317059
# -----100 tweets collected at 2018-04-16 23:53:33.302068.
# -----200 tweets collected at 2018-04-16 23:53:38.007899.
# -----300 tweets collected at 2018-04-16 23:53:42.724694.
# -----340 "my nutritionist" tweets collected in 0:00:36.406065 seconds.
# Collecting "my foodstamps" tweets from 2014-10-01 to 2014-11-01 at 2018-04-16 23:53:44.723301
# -----100 tweets collected at 2018-04-16 23:54:04.462967.
# -----200 tweets collected at 2018-04-16 23:54:08.914354.
# -----243 "my foodstamps" tweets collected in 0:00:26.163807 seconds.
# Collecting "my nutritionist" tweets from 2014-12-01 to 2014-1-01 at 2018-04-16 23:54:10.887375
# -----0 "my nutritionist" tweets collected in 0:00:05.177468 seconds.
# Collecting "my foodstamps" tweets from 2014-12-01 to 2014-1-01 at 2018-04-16 23:54:16.065029
# -----0 "my foodstamps" tweets collected in 0:00:05.146947 seconds.
# Collecting "my nutritionist" tweets from 2015-2-01 to 2015-3-01 at 2018-04-16 23:54:21.212331
# -----100 tweets collected at 2018-04-16 23:54:52.965056.
# -----200 tweets collected at 2018-04-16 23:54:58.675073.
# -----300 tweets collected at 2018-04-16 23:55:04.452808.
# -----400 tweets collected at 2018-04-16 23:55:10.523930.
# -----476 "my nutritionist" tweets collected in 0:00:53.842228 seconds.
# Collecting "my foodstamps" tweets from 2015-2-01 to 2015-3-01 at 2018-04-16 23:55:15.054842
# -----100 tweets collected at 2018-04-16 23:55:30.770030.
# -----139 "my foodstamps" tweets collected in 0:00:17.484548 seconds.
# Collecting "my nutritionist" tweets from 2015-4-01 to 2015-5-01 at 2018-04-16 23:55:32.539633
# -----100 tweets collected at 2018-04-16 23:56:00.382109.
# -----200 tweets collected at 2018-04-16 23:56:05.834413.
# -----300 tweets collected at 2018-04-16 23:56:11.441099.
# -----352 "my nutritionist" tweets collected in 0:00:41.700890 seconds.
# Collecting "my foodstamps" tweets from 2015-4-01 to 2015-5-01 at 2018-04-16 23:56:14.240703
# -----100 tweets collected at 2018-04-16 23:56:31.715200.
# -----152 "my foodstamps" tweets collected in 0:00:19.760969 seconds.
# Collecting "my nutritionist" tweets from 2015-6-01 to 2015-7-01 at 2018-04-16 23:56:34.001951
# -----100 tweets collected at 2018-04-16 23:56:56.769156.
# -----200 tweets collected at 2018-04-16 23:57:02.169880.
# -----292 "my nutritionist" tweets collected in 0:00:32.751029 seconds.
# Collecting "my foodstamps" tweets from 2015-6-01 to 2015-7-01 at 2018-04-16 23:57:06.753616
# -----100 tweets collected at 2018-04-16 23:57:22.190027.
# -----119 "my foodstamps" tweets collected in 0:00:16.314953 seconds.
# Collecting "my nutritionist" tweets from 2015-8-01 to 2015-9-01 at 2018-04-16 23:57:23.068851
# -----100 tweets collected at 2018-04-16 23:57:46.384428.
# -----200 tweets collected at 2018-04-16 23:57:51.095625.
# -----300 tweets collected at 2018-04-16 23:57:56.111677.
# -----301 "my nutritionist" tweets collected in 0:00:33.184849 seconds.
# Collecting "my foodstamps" tweets from 2015-8-01 to 2015-9-01 at 2018-04-16 23:57:56.253859
# -----100 tweets collected at 2018-04-16 23:58:11.252746.
# -----105 "my foodstamps" tweets collected in 0:00:15.318517 seconds.
# Collecting "my nutritionist" tweets from 2015-10-01 to 2015-11-01 at 2018-04-16 23:58:11.572805
# -----100 tweets collected at 2018-04-16 23:58:35.102892.
# -----200 tweets collected at 2018-04-16 23:58:40.056717.
# -----300 tweets collected at 2018-04-16 23:58:45.085286.
# -----300 "my nutritionist" tweets collected in 0:00:33.689566 seconds.
# Collecting "my foodstamps" tweets from 2015-10-01 to 2015-11-01 at 2018-04-16 23:58:45.262562
# -----98 "my foodstamps" tweets collected in 0:00:14.071726 seconds.
# Collecting "my nutritionist" tweets from 2015-12-01 to 2015-1-01 at 2018-04-16 23:58:59.334579
# -----0 "my nutritionist" tweets collected in 0:00:05.535156 seconds.
# Collecting "my foodstamps" tweets from 2015-12-01 to 2015-1-01 at 2018-04-16 23:59:04.869936
# -----0 "my foodstamps" tweets collected in 0:00:06.047186 seconds.
# Collecting "my nutritionist" tweets from 2016-2-01 to 2016-3-01 at 2018-04-16 23:59:10.917443
# -----100 tweets collected at 2018-04-16 23:59:33.120777.
# -----200 tweets collected at 2018-04-16 23:59:37.571275.
# -----273 "my nutritionist" tweets collected in 0:00:30.207951 seconds.
# Collecting "my foodstamps" tweets from 2016-2-01 to 2016-3-01 at 2018-04-16 23:59:41.126024
# -----88 "my foodstamps" tweets collected in 0:00:14.305542 seconds.
# Collecting "my nutritionist" tweets from 2016-4-01 to 2016-5-01 at 2018-04-16 23:59:55.431873
# -----100 tweets collected at 2018-04-17 00:00:18.629209.
# -----200 tweets collected at 2018-04-17 00:00:24.169929.
# -----290 "my nutritionist" tweets collected in 0:00:35.228744 seconds.
# Collecting "my foodstamps" tweets from 2016-4-01 to 2016-5-01 at 2018-04-17 00:00:30.660822
# -----62 "my foodstamps" tweets collected in 0:00:11.949329 seconds.
# Collecting "my nutritionist" tweets from 2016-6-01 to 2016-7-01 at 2018-04-17 00:00:42.610467
# -----100 tweets collected at 2018-04-17 00:01:09.403476.
# -----200 tweets collected at 2018-04-17 00:01:14.401531.
# -----281 "my nutritionist" tweets collected in 0:00:37.098030 seconds.
# Collecting "my foodstamps" tweets from 2016-6-01 to 2016-7-01 at 2018-04-17 00:01:19.708656
# -----89 "my foodstamps" tweets collected in 0:00:15.296902 seconds.
# Collecting "my nutritionist" tweets from 2016-8-01 to 2016-9-01 at 2018-04-17 00:01:35.005880
# -----100 tweets collected at 2018-04-17 00:02:01.701722.
# -----200 tweets collected at 2018-04-17 00:02:06.699505.
# -----291 "my nutritionist" tweets collected in 0:00:36.968938 seconds.
# Collecting "my foodstamps" tweets from 2016-8-01 to 2016-9-01 at 2018-04-17 00:02:11.974988
# -----98 "my foodstamps" tweets collected in 0:00:14.436183 seconds.
# Collecting "my nutritionist" tweets from 2016-10-01 to 2016-11-01 at 2018-04-17 00:02:26.411544
# -----100 tweets collected at 2018-04-17 00:02:46.461232.
# -----200 tweets collected at 2018-04-17 00:02:50.870888.
# -----207 "my nutritionist" tweets collected in 0:00:24.927474 seconds.
# Collecting "my foodstamps" tweets from 2016-10-01 to 2016-11-01 at 2018-04-17 00:02:51.339184
# -----87 "my foodstamps" tweets collected in 0:00:12.696850 seconds.
# Collecting "my nutritionist" tweets from 2016-12-01 to 2016-1-01 at 2018-04-17 00:03:04.036381
# -----0 "my nutritionist" tweets collected in 0:00:05.188593 seconds.
# Collecting "my foodstamps" tweets from 2016-12-01 to 2016-1-01 at 2018-04-17 00:03:09.225184
# -----0 "my foodstamps" tweets collected in 0:00:05.106238 seconds.
# Collecting "my nutritionist" tweets from 2017-2-01 to 2017-3-01 at 2018-04-17 00:03:14.331730
# -----100 tweets collected at 2018-04-17 00:03:34.846879.
# -----200 tweets collected at 2018-04-17 00:03:39.483416.
# -----237 "my nutritionist" tweets collected in 0:00:26.861501 seconds.
# Collecting "my foodstamps" tweets from 2017-2-01 to 2017-3-01 at 2018-04-17 00:03:41.193390
# -----58 "my foodstamps" tweets collected in 0:00:09.975662 seconds.
# Collecting "my nutritionist" tweets from 2017-4-01 to 2017-5-01 at 2018-04-17 00:03:51.169330
# -----100 tweets collected at 2018-04-17 00:04:13.997877.
# -----200 tweets collected at 2018-04-17 00:04:18.996022.
# -----259 "my nutritionist" tweets collected in 0:00:30.626365 seconds.
# Collecting "my foodstamps" tweets from 2017-4-01 to 2017-5-01 at 2018-04-17 00:04:21.795869
# -----64 "my foodstamps" tweets collected in 0:00:10.978569 seconds.
# Collecting "my nutritionist" tweets from 2017-6-01 to 2017-7-01 at 2018-04-17 00:04:32.774786
# -----100 tweets collected at 2018-04-17 00:04:58.854396.
# -----200 tweets collected at 2018-04-17 00:05:04.683521.
# -----279 "my nutritionist" tweets collected in 0:00:35.922943 seconds.
# Collecting "my foodstamps" tweets from 2017-6-01 to 2017-7-01 at 2018-04-17 00:05:08.697928
# -----48 "my foodstamps" tweets collected in 0:00:09.976478 seconds.
# Collecting "my nutritionist" tweets from 2017-8-01 to 2017-9-01 at 2018-04-17 00:05:18.674761
# -----100 tweets collected at 2018-04-17 00:05:44.934755.
# -----200 tweets collected at 2018-04-17 00:05:49.435736.
# -----273 "my nutritionist" tweets collected in 0:00:34.796110 seconds.
# Collecting "my foodstamps" tweets from 2017-8-01 to 2017-9-01 at 2018-04-17 00:05:53.471050
# -----78 "my foodstamps" tweets collected in 0:00:17.552489 seconds.
# Collecting "my nutritionist" tweets from 2017-10-01 to 2017-11-01 at 2018-04-17 00:06:11.023875
# -----100 tweets collected at 2018-04-17 00:06:44.311076.
# -----200 tweets collected at 2018-04-17 00:06:49.139839.
# -----248 "my nutritionist" tweets collected in 0:00:40.605240 seconds.
# Collecting "my foodstamps" tweets from 2017-10-01 to 2017-11-01 at 2018-04-17 00:06:51.629329
# -----81 "my foodstamps" tweets collected in 0:00:15.792887 seconds.
# Collecting "my nutritionist" tweets from 2017-12-01 to 2017-1-01 at 2018-04-17 00:07:07.422571
# -----0 "my nutritionist" tweets collected in 0:00:05.546207 seconds.
# Collecting "my foodstamps" tweets from 2017-12-01 to 2017-1-01 at 2018-04-17 00:07:12.969032
# -----0 "my foodstamps" tweets collected in 0:00:05.879426 seconds.
# Collecting "my nutritionist" tweets from 2018-2-01 to 2018-3-01 at 2018-04-17 00:07:18.848751
# -----100 tweets collected at 2018-04-17 00:07:47.411279.
# -----200 tweets collected at 2018-04-17 00:07:52.419335.
# -----300 tweets collected at 2018-04-17 00:07:58.579508.
# -----320 "my nutritionist" tweets collected in 0:00:40.874630 seconds.
# Collecting "my foodstamps" tweets from 2018-2-01 to 2018-3-01 at 2018-04-17 00:07:59.724853
# -----66 "my foodstamps" tweets collected in 0:00:11.363407 seconds.
# Total Time: 0:30:36.027329

# %%
#steps to remove retweets and tweets from duplicate accounts
import pandas as pd
import numpy as np


d = pd.read_json('food_risk_train_set2.json')
print(d.groupby('label')['marker_tweet'].count())


d['upper_tweet']=d.marker_tweet.str.upper()

d = d[d.upper_tweet.str.contains('"') == False]

d = d[d.marker_tweet.str.contains("RT") == False]


dedup1 = d.drop_duplicates(['username','marker_tweet'],False)
dedup2 = dedup1.sort_values('marker_tweet_id').drop_duplicates(['username'],keep='last')

dedup2.to_json(path_or_buf='dedup_food_train_set_4_16.json',orient='records')
